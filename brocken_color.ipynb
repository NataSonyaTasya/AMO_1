# %% [markdown]
# <a href="https://colab.research.google.com/github/NataSonyaTasya/AMO_1/blob/main/brocken_color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/train_dataset_altai.zip

# %%
import pandas as pd
import matplotlib.pyplot as plt # библиотека MatPlotLib для визуализации
import seaborn as sns; sns.set() # библиотека Seaborn для визуализации данных из Pandas
import PIL
import os # чтение файлов и структуры директорий
import numpy as np
from PIL import Image
# %matplotlib inline

# %%
import cv2 # импорт Open CV
from google.colab.patches import cv2_imshow # cv2_imshow служит для отображения картинок в Google Colab

# %%
def colors(grey_image): #функция искать одноцветные области брака
  b=0
  n=np.array(gray_image)
  unique, counts = np.unique(np.ravel(grey_image), return_counts=True)
  for i in range(len(n[:,0])):
      if len(np.unique(np.array(n[i,:])))==1 :
        uno=np.unique(np.array(n[i,:]), return_counts=False)
        if uno!=0:
           if uno!=255:
             b+=1
  if b>25:
    br=1

  elif len(np.array(unique))<7:
    br=1
  elif (max(np.array(counts))/len(np.ravel(grey_image)))>0.25:

    if np.mean(n)<240:
           br=0
           if  np.mean(n)<70:
                   br=0
           else: br=1

    else: br=1
   # print(max(np.array(counts))/len(n))
  #  br=1
  else :
    br=0

  return br

# %%
def koeff(grey_image):#соотношения белого, черного, серединки
    n=np.ravel(gray_image)
    av=np.mean(n)
    koef_bl=sum(n>240)/len(n)
    koef_wt=sum(n<10)/len(n)
    koef_av=(sum(n<(av+10))-sum(n<(av-10)))/len(n)
    return (av,koef_bl,koef_wt,koef_av)

# %%
def save_file_at_dir(dir_path, img, fldr):
    os.makedirs(dir_path, exist_ok=True)
    os.chdir(dir_path)
    cv2.imwrite("{}.jpg".format(fldr), img)

# %%
def chanal_bad(img):#ошибки в каналах
  r = img[:,:,0]
  g= img[:,:,1]
  b= img[:,:,2]
  rr=np.ravel(r)
  gr=np.ravel(g)
  br=np.ravel(b)
  if np.mean(rr)>2*np.mean(gr) or np.mean(rr)>2*sum(br):
    br=1
  elif np.mean(gr)>2*np.mean(rr) or np.mean(gr)>2*np.mean(br):
    br=1
  elif np.mean(br)>2*np.mean(gr) or np.mean(br)>2*np.mean(rr):
    br=1
  else:
    br=0
  return br

# %%
from logging import exception#распределяет по 2 папкам хорошие - битые
directory='/content/imgs'
brocken_img=[]
exception1=[]
i=1
br=0
br_path="/content/b"
good_path="/content/g"
for fldr in os.listdir(directory):
     file_path = os.path.join(directory, fldr)
     try:
            im = Image.open(file_path)
            im=cv2.imread(file_path)
            gray_image = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            av,koef_bl,koef_wt,koef_av=koeff(gray_image)
            if av <=10 or av>=240:
              br=1
            elif koef_bl>0.8 or koef_av>0.8 or koef_wt>0.8:
                  br=1
            else :
              br=colors(gray_image)

              if br==0:
                br=chanal_bad(im)
            if br:
               brocken_img.append(fldr.split('.')[0])
               save_file_at_dir(br_path,im,fldr)
            else:
               save_file_at_dir(good_path,im,fldr)
     except PIL.UnidentifiedImageError:
            extensions1.append(fldr.split('.')[0])
# Out:
#         0
# 331     0
# 2082    1
# 3049    2
# 2690    3
# 3160    4
# ...   ...
# 2201  251
# 2429  252
# 3096  253
# 3785  254
# 849   255
#
# [256 rows x 1 columns]
# 1448
#          0
# 3054     0
# 18170    1
# 23114    2
# 18220    3
# 18895    4
# ...    ...
# 3216   251
# 3481   252
# 4552   253
# 5874   254
# 1204   255
#
# [256 rows x 1 columns]
# 392
#           0
# 10795     0
# 1668      1
# 1295      2
# 684       3
# 799       4
# ...     ...
# 965     251
# 1728    252
# 3883    253
# 6742    254
# 226557  255
#
# [145 rows x 1 columns]
# 0
# 21.68168120967332 121.01239827039831 12.260468265762333
#           0
# 10410     0
# 2494      1
# 697       2
# 632       3
# 490       4
# ...     ...
# 678     251
# 1325    252
# 3198    253
# 8016    254
# 227950  255
#
# [151 rows x 1 columns]
# 0
# 22.92062788954936 114.47006696768786 12.307345250342935
#           0
# 109601    0
# 3953      1
# 6584      2
# 14179     3
# 31758     4
# ...     ...
# 5371    251
# 6051    252
# 8674    253
# 17585   254
# 29622   255
#
# [256 rows x 1 columns]
# 0
# 179.27803579966226 79.49503644307454 143.86832777659097
#           0
# 17474     0
# 2727      1
# 1098      2
# 339       3
# 41        4
# ...     ...
# 50      251
# 614     252
# 1856    253
# 7189    254
# 294999  255
#
# [138 rows x 1 columns]
# 0
# 201.6376239757545 201.6376239757545 201.6376239757545
#           0
# 10425     0
# 2245      1
# 982       2
# 569       3
# 403       4
# ...     ...
# 556     251
# 848     252
# 2601    253
# 8958    254
# 226797  255
#
# [247 rows x 1 columns]
# 0
# 66.80681874110908 98.83008318568054 79.46960773573642
#          0
# 500      0
# 3872     1
# 7573     2
# 6883     3
# 8553     4
# ...    ...
# 7325   251
# 8755   252
# 10889  253
# 14786  254
# 3903   255
#
# [256 rows x 1 columns]
# 624
#         0
# 893     0
# 5167    1
# 8185    2
# 6851    3
# 8175    4
# ...   ...
# 179   251
# 127   252
# 125   253
# 229   254
# 20    255
#
# [256 rows x 1 columns]
# 1408
#           0
# 9991      0
# 1272      1
# 913       2
# 823       3
# 423       4
# ...     ...
# 1701    251
# 2507    252
# 3817    253
# 4986    254
# 225858  255
#
# [183 rows x 1 columns]
# 0
# 24.499349256020423 187.32364222933495 12.375370322740435
#         0
# 928     0
# 5129    1
# 7981    2
# 6878    3
# 8021    4
# ...   ...
# 119   250
# 121   251
# 105   252
# 57    253
# 32    254
#
# [255 rows x 1 columns]
# 1512
#          0
# 483      0
# 3561     1
# 7328     2
# 6609     3
# 8632     4
# ...    ...
# 6024   251
# 7321   252
# 8840   253
# 11962  254
# 3536   255
#
# [256 rows x 1 columns]
# 800
#         0
# 261     0
# 2339    1
# 4912    2
# 4707    3
# 5792    4
# ...   ...
# 400   251
# 401   252
# 389   253
# 256   254
# 43    255
#
# [256 rows x 1 columns]
# 656
#         0
# 1027    0
# 5936    1
# 9580    2
# 8099    3
# 9543    4
# ...   ...
# 650   251
# 566   252
# 740   253
# 1071  254
# 188   255
#
# [256 rows x 1 columns]
# 1416
#           0
# 9996      0
# 1822      1
# 826       2
# 835       3
# 480       4
# ...     ...
# 1056    251
# 2411    252
# 3394    253
# 7250    254
# 225576  255
#
# [140 rows x 1 columns]
# 0
# 18.136239275326425 148.56612801179952 12.287119397132043
#           0
# 10387     0
# 1018      1
# 573       2
# 340       3
# 776       4
# ...     ...
# 1803    251
# 2085    252
# 3399    253
# 5181    254
# 227612  255
#
# [179 rows x 1 columns]
# 0
# 23.586219905819743 177.24111106348118 12.38383971891988
#         0
# 665     0
# 2814    1
# 3744    2
# 2895    3
# 3419    4
# ...   ...
# 43    250
# 52    251
# 30    252
# 45    253
# 6     254
#
# [255 rows x 1 columns]
# 744
#          0
# 622      0
# 4270     1
# 7308     2
# 6713     3
# 8774     4
# ...    ...
# 7067   251
# 8604   252
# 11403  253
# 14811  254
# 4681   255
#
# [256 rows x 1 columns]
# 696
#           0
# 9640      0
# 2147      1
# 1077      2
# 463       3
# 446       4
# ...     ...
# 1017    251
# 1619    252
# 4496    253
# 7302    254
# 226154  255
#
# [152 rows x 1 columns]
# 0
# 16.578279201912817 158.71814271833563 12.311649408753746
#           0
# 18055     0
# 2826      1
# 1150      2
# 261       3
# 86        4
# ...     ...
# 114     251
# 646     252
# 2273    253
# 6805    254
# 294166  255
#
# [195 rows x 1 columns]
# 0
# 197.96222619204954 197.96222619204954 197.96222619204954
#           0
# 109480    0
# 4597      1
# 6431      2
# 6637      3
# 7695      4
# ...     ...
# 2623    251
# 2569    252
# 4476    253
# 8710    254
# 241025  255
#
# [256 rows x 1 columns]
# 0
# 115.15270964304607 90.01415729522705 113.31938711802165
#           0
# 10594     0
# 1682      1
# 1229      2
# 601       3
# 295       4
# ...     ...
# 1319    251
# 2017    252
# 3737    253
# 11693   254
# 276774  255
#
# [256 rows x 1 columns]
# 0
# 146.14895400306773 187.71061573373223 112.41307617562957
#           0
# 10459     0
# 2913      1
# 969       2
# 2100      3
# 7838      4
# ...     ...
# 638     251
# 1037    252
# 2947    253
# 6657    254
# 230243  255
#
# [137 rows x 1 columns]
# 0
# 20.283438198572373 85.04797941910532 12.282537000520755
#           0
# 10958     0
# 2217      1
# 648       2
# 602       3
# 637       4
# ...     ...
# 914     251
# 1452    252
# 3076    253
# 7409    254
# 227113  255
#
# [153 rows x 1 columns]
# 0
# 20.967002576779453 124.56281078532236 12.259440451468272
#          0
# 1042     0
# 6023     1
# 9846     2
# 8770     3
# 10463    4
# ...    ...
# 1173   251
# 1080   252
# 1537   253
# 1899   254
# 321    255
#
# [256 rows x 1 columns]
# 1320
#          0
# 1972     0
# 10829    1
# 16196    2
# 13933    3
# 15628    4
# ...    ...
# 6961   251
# 5742   252
# 6340   253
# 9224   254
# 3739   255
#
# [256 rows x 1 columns]
# 616
#         0
# 704     0
# 4473    1
# 7910    2
# 6886    3
# 8723    4
# ...   ...
# 89    251
# 60    252
# 44    253
# 46    254
# 6     255
#
# [256 rows x 1 columns]
# 1536
#           0
# 9812      0
# 2180      1
# 1064      2
# 528       3
# 576       4
# ...     ...
# 963     251
# 1669    252
# 4458    253
# 7395    254
# 225694  255
#
# [148 rows x 1 columns]
# 0
# 16.694088410684348 156.76842206790124 12.295174412881675
#           0
# 10300     0
# 1576      1
# 1040      2
# 406       3
# 519       4
# ...     ...
# 911     251
# 1228    252
# 3134    253
# 5015    254
# 228772  255
#
# [256 rows x 1 columns]
# 0
# 128.63562663529441 139.75055647640096 130.82332608564496
#           0
# 109581    0
# 3523      1
# 4318      2
# 4377      3
# 4265      4
# ...     ...
# 7864    251
# 7045    252
# 11099   253
# 17479   254
# 40469   255
#
# [256 rows x 1 columns]
# 0
# 153.24721495310465 113.26883920033772 139.57325299580893
#         0
# 237     0
# 1239    1
# 2009    2
# 1570    3
# 1734    4
# ...   ...
# 45    251
# 23    252
# 26    253
# 31    254
# 6     255
#
# [256 rows x 1 columns]
# 1672
#           0
# 10847     0
# 2563      1
# 739       2
# 3446      3
# 10560     4
# ...     ...
# 690     251
# 1560    252
# 3163    253
# 7548    254
# 227351  255
#
# [134 rows x 1 columns]
# 0
# 13.233788556431946 96.50244639250876 12.255965053917086
#           0
# 9985      0
# 1920      1
# 822       2
# 862       3
# 504       4
# ...     ...
# 871     251
# 2230    252
# 3577    253
# 7514    254
# 225643  255
#
# [136 rows x 1 columns]
# 0
# 17.53360073572372 141.7617362143093 12.286271981214753
#           0
# 9331      0
# 2170      1
# 1078      2
# 395       3
# 512       4
# ...     ...
# 1893    251
# 2476    252
# 4822    253
# 3785    254
# 225796  255
#
# [183 rows x 1 columns]
# 0
# 18.67560958377788 173.59339674465275 12.348113298912768
#          0
# 2733     0
# 14706    1
# 20547    2
# 16062    3
# 17367    4
# ...    ...
# 3594   251
# 3642   252
# 4830   253
# 6320   254
# 1906   255
#
# [256 rows x 1 columns]
# 576
#          0
# 581      0
# 4199     1
# 7868     2
# 7063     3
# 8907     4
# ...    ...
# 8038   251
# 9278   252
# 11060  253
# 13138  254
# 4826   255
#
# [256 rows x 1 columns]
# 720
#           0
# 9936      0
# 1961      1
# 816       2
# 849       3
# 487       4
# ...     ...
# 872     251
# 2256    252
# 3562    253
# 7471    254
# 225649  255
#
# [136 rows x 1 columns]
# 0
# 17.57056990010415 141.56173911179698 12.285607345170959
#           0
# 10063     0
# 783       1
# 1322      2
# 1027      3
# 396       4
# ...     ...
# 1782    251
# 2526    252
# 4544    253
# 4333    254
# 225321  255
#
# [184 rows x 1 columns]
# 0
# 25.33568724438602 195.56785816916883 12.352017167416044
#           0
# 11310     0
# 2273      1
# 970       2
# 1595      3
# 7157      4
# ...     ...
# 689     251
# 1210    252
# 3236    253
# 7449    254
# 228582  255
#
# [136 rows x 1 columns]
# 0
# 20.92662807054311 87.19425829078392 12.266346196590966
#        0
# 55     0
# 214    1
# 359    2
# 239    3
# 200    4
# ..   ...
# 11   248
# 2    250
# 2    251
# 2    253
# 3    254
#
# [247 rows x 1 columns]
# 1872
#           0
# 9884      0
# 1909      1
# 678       2
# 831       3
# 461       4
# ...     ...
# 1014    251
# 2219    252
# 3462    253
# 7217    254
# 226085  255
#
# [142 rows x 1 columns]
# 0
# 18.062394817228064 148.82008407477264 12.30114740512117
#           0
# 10391     0
# 2479      1
# 701       2
# 650       3
# 501       4
# ...     ...
# 685     251
# 1334    252
# 3057    253
# 8029    254
# 228015  255
#
# [151 rows x 1 columns]
# 0
# 22.920106540225067 114.4957222365112 12.306503986625515
#           0
# 10414     0
# 2193      1
# 1004      2
# 583       3
# 398       4
# ...     ...
# 531     251
# 853     252
# 2587    253
# 8998    254
# 226670  255
#
# [245 rows x 1 columns]
# 0
# 66.92793154308286 98.77049119163745 79.47081713915561
#           0
# 109217    0
# 3849      1
# 7220      2
# 9549      3
# 8239      4
# ...     ...
# 16050   251
# 13822   252
# 18011   253
# 17556   254
# 11264   255
#
# [256 rows x 1 columns]
# 0
# 142.29465198516846 103.06054147084554 136.84350109100342
#           0
# 8041      0
# 2361      1
# 1246      2
# 428       3
# 819       4
# ...     ...
# 16689   251
# 9525    252
# 7447    253
# 8056    254
# 233198  255
#
# [256 rows x 1 columns]
# 0
# 109.12415516403749 154.702446471892 135.25963672648987
#           0
# 11       34
# 4        39
# 1        43
# 1        44
# 1        46
# ...     ...
# 41795   251
# 6626    252
# 5442    253
# 408110  254
# 8686    255
#
# [207 rows x 1 columns]
# 0
# 182.26795959472656 151.99356524149576 179.03183682759604
#          0
# 2911     0
# 17195    1
# 21748    2
# 17497    3
# 19092    4
# ...    ...
# 4529   251
# 4769   252
# 6086   253
# 8545   254
# 3057   255
#
# [256 rows x 1 columns]
# 272
#           0
# 109358    0
# 8460      1
# 14618     2
# 10022     3
# 10859     4
# ...     ...
# 2268    251
# 2087    252
# 3745    253
# 7749    254
# 298248  255
#
# [256 rows x 1 columns]
# 0
# 125.96533584594727 124.46825377146403 138.59729703267416
#           0
# 109232    0
# 5014      1
# 8434      2
# 11321     3
# 14476     4
# ...     ...
# 2036    251
# 1784    252
# 2349    253
# 3904    254
# 148182  255
#
# [256 rows x 1 columns]
# 0
# 123.42154026031494 101.85293261210124 126.530411084493
#           0
# 9301      0
# 2139      1
# 1080      2
# 413       3
# 474       4
# ...     ...
# 1983    251
# 2519    252
# 4793    253
# 3770    254
# 225818  255
#
# [184 rows x 1 columns]
# 0
# 18.564293862406647 173.57506795203983 12.35245714893563
#           0
# 11186     0
# 2018      1
# 941       2
# 561       3
# 540       4
# ...     ...
# 570     251
# 935     252
# 2700    253
# 6988    254
# 230739  255
#
# [126 rows x 1 columns]
# 0
# 21.56401760878677 128.94793174947924 12.303031565945233
#         0
# 257     0
# 2212    1
# 4886    2
# 4472    3
# 5481    4
# ...   ...
# 442   251
# 436   252
# 379   253
# 259   254
# 31    255
#
# [256 rows x 1 columns]
# 1336
#         0
# 37      0
# 268     1
# 706     2
# 861     3
# 1128    4
# ...   ...
# 3     251
# 9     252
# 2     253
# 3     254
# 1     255
#
# [236 rows x 1 columns]
# 2072
#           0
# 109194    0
# 2993      1
# 2942      2
# 3223      3
# 3966      4
# ...     ...
# 522     251
# 338     252
# 338     253
# 811     254
# 6255    255
#
# [256 rows x 1 columns]
# 0
# 155.3548672993978 106.40436871846516 146.99844137827554
#           0
# 110743    0
# 3092      1
# 2267      2
# 1674      3
# 1749      4
# ...     ...
# 672     251
# 503     252
# 414     253
# 923     254
# 6425    255
#
# [256 rows x 1 columns]
# 0
# 100.58767414093018 100.5889081954956 100.76958974202473
#         0
# 618     0
# 3609    1
# 6503    2
# 6073    3
# 8255    4
# ...   ...
# 7250  251
# 8100  252
# 8324  253
# 8169  254
# 2472  255
#
# [256 rows x 1 columns]
# 0
#           0
# 19095     0
# 2667      1
# 217       2
# 15        3
# 1       138
# ...     ...
# 208873  251
# 235471  252
# 253911  253
# 553334  254
# 298466  255
#
# [122 rows x 1 columns]
# 0
# 230.3673968796056 230.3673968796056 230.3673968796056
#           0
# 10359     0
# 1685      1
# 1212      2
# 686       3
# 347       4
# ...     ...
# 1407    251
# 2079    252
# 3583    253
# 11470   254
# 277054  255
#
# [256 rows x 1 columns]
# 0
# 137.01086671392414 182.9003746055203 103.76057398296328
#         0
# 268     0
# 2080    1
# 4992    2
# 4753    3
# 6068    4
# ...   ...
# 424   251
# 456   252
# 410   253
# 316   254
# 37    255
#
# [256 rows x 1 columns]
# 1512
#         0
# 1109    0
# 5315    1
# 8633    2
# 7335    3
# 8548    4
# ...   ...
# 60    250
# 44    251
# 55    252
# 33    253
# 7     254
#
# [255 rows x 1 columns]
# 1576
#           0
# 10958     0
# 2054      1
# 851       2
# 700       3
# 924       4
# ...     ...
# 812     251
# 1293    252
# 3478    253
# 7097    254
# 227551  255
#
# [142 rows x 1 columns]
# 0
# 21.97842919651476 105.12252919714983 12.263455059569171
#         0
# 195     0
# 1824    1
# 3361    2
# 3172    3
# 4230    4
# ...   ...
# 649   251
# 610   252
# 462   253
# 272   254
# 22    255
#
# [256 rows x 1 columns]
# 1768
#           0
# 10635     0
# 2733      1
# 757       2
# 1179      3
# 2390      4
# ...     ...
# 772     251
# 1281    252
# 3219    253
# 7748    254
# 228115  255
#
# [148 rows x 1 columns]
# 0
# 20.749351042142965 89.00227432937052 12.279933826144388
#        0
# 88     0
# 367    1
# 661    2
# 698    3
# 962    4
# ..   ...
# 10   249
# 7    250
# 6    251
# 4    252
# 2    254
#
# [254 rows x 1 columns]
# 1592
#           0
# 111535    0
# 4235      1
# 5228      2
# 11203     3
# 29082     4
# ...     ...
# 588     251
# 350     252
# 363     253
# 1045    254
# 6709    255
#
# [256 rows x 1 columns]
# 0
# 43.04612890879313 43.04726378122965 43.22767861684164
#         0
# 716     0
# 4431    1
# 8121    2
# 7152    3
# 8896    4
# ...   ...
# 100   251
# 98    252
# 54    253
# 34    254
# 11    255
#
# [256 rows x 1 columns]
# 1512
#         0
# 148     0
# 1385    1
# 3408    2
# 3069    3
# 3913    4
# ...   ...
# 312   251
# 355   252
# 287   253
# 203   254
# 16    255
#
# [256 rows x 1 columns]
# 1256
#           0
# 9981      0
# 1897      1
# 815       2
# 866       3
# 472       4
# ...     ...
# 1014    251
# 2291    252
# 3554    253
# 7403    254
# 225541  255
#
# [137 rows x 1 columns]
# 0
# 17.601285055631763 141.74802236542956 12.285532328024184
#           0
# 9944      0
# 1359      1
# 842       2
# 861       3
# 477       4
# ...     ...
# 1655    251
# 2398    252
# 4032    253
# 4916    254
# 225923  255
#
# [181 rows x 1 columns]
# 0
# 24.670634041749224 187.97354970818728 12.377237019255196
#           0
# 10225     0
# 2228      1
# 976       2
# 534       3
# 386       4
# ...     ...
# 540     251
# 806     252
# 2605    253
# 8634    254
# 227608  255
#
# [244 rows x 1 columns]
# 0
# 66.77514046861505 98.78062803243915 79.47191937522227
#           0
# 11177     0
# 2031      1
# 914       2
# 589       3
# 669       4
# ...     ...
# 554     251
# 863     252
# 2631    253
# 6934    254
# 230954  255
#
# [127 rows x 1 columns]
# 0
# 21.575367028336636 128.8484451207895 12.303120078240106
#           0
# 10200     0
# 1009      1
# 573       2
# 325       3
# 753       4
# ...     ...
# 1797    251
# 1992    252
# 3413    253
# 5173    254
# 228066  255
#
# [178 rows x 1 columns]
# 0
# 23.534033969669256 177.89508236803331 12.401751749606259
#           0
# 10712     0
# 11513     1
# 20427     2
# 19529     3
# 22365     4
# ...     ...
# 3368    251
# 3380    252
# 4656    253
# 9797    254
# 275121  255
#
# [256 rows x 1 columns]
# 0
# 85.89310226235102 107.53882145689158 95.64897915865693
#         0
# 828     0
# 4698    1
# 6864    2
# 5495    3
# 6294    4
# ...   ...
# 82    251
# 86    252
# 112   253
# 57    254
# 4     255
#
# [256 rows x 1 columns]
# 0
# 48.27158850161797 44.90112802167435 107.50023178184672
#        0
# 52     0
# 200    1
# 235    2
# 168    3
# 194    4
# ..   ...
# 26   251
# 24   252
# 24   253
# 23   254
# 1    255
#
# [256 rows x 1 columns]
# 1696
#         0
# 294     0
# 1130    1
# 1106    2
# 973     3
# 1141    4
# ...   ...
# 1911  251
# 1109  252
# 629   253
# 482   254
# 78    255
#
# [256 rows x 1 columns]
# 0
# 222.68201808399013 206.55226768250193 218.26332783164327
#           0
# 10871     0
# 2512      1
# 744       2
# 637       3
# 537       4
# ...     ...
# 859     251
# 1510    252
# 3273    253
# 7373    254
# 226518  255
#
# [153 rows x 1 columns]
# 0
# 21.017824113765688 126.09044865016766 12.243099811702992
#           0
# 9653      0
# 2308      1
# 819       2
# 427       3
# 423       4
# ...     ...
# 1551    251
# 2433    252
# 4841    253
# 4323    254
# 225583  255
#
# [181 rows x 1 columns]
# 0
# 24.87319502394198 195.13159495980034 12.349083957285474
#          0
# 1003     0
# 5793     1
# 10430    2
# 9153     3
# 11111    4
# ...    ...
# 3575   251
# 2793   252
# 3223   253
# 5091   254
# 2437   255
#
# [256 rows x 1 columns]
# 1184
#          0
# 1011     0
# 5682     1
# 9141     2
# 7858     3
# 9158     4
# ...    ...
# 18029  251
# 13463  252
# 8991   253
# 4365   254
# 202    255
#
# [256 rows x 1 columns]
# 1352
#           0
# 9887      0
# 1886      1
# 714       2
# 818       3
# 445       4
# ...     ...
# 1015    251
# 2196    252
# 3530    253
# 7245    254
# 225997  255
#
# [141 rows x 1 columns]
# 0
# 18.146922074251894 148.68405873723518 12.301105927386578
#         0
# 1095    0
# 5923    1
# 9473    2
# 7883    3
# 9568    4
# ...   ...
# 438   251
# 456   252
# 593   253
# 801   254
# 100   255
#
# [256 rows x 1 columns]
# 1432
#         0
# 903     0
# 5276    1
# 8438    2
# 7168    3
# 8230    4
# ...   ...
# 74    251
# 46    252
# 34    253
# 16    254
# 3     255
#
# [256 rows x 1 columns]
# 1616
#           0
# 109422    0
# 2727      1
# 2347      2
# 1879      3
# 2121      4
# ...     ...
# 17482   251
# 15891   252
# 20387   253
# 24246   254
# 39618   255
#
# [256 rows x 1 columns]
# 0
# 144.55434703826904 136.12633736928305 159.3934809366862
#         0
# 1076    0
# 5441    1
# 8474    2
# 6860    3
# 8300    4
# ...   ...
# 73    250
# 44    251
# 35    252
# 53    253
# 1     254
#
# [255 rows x 1 columns]
# 0
# 39.04557354242759 77.07213872068435 41.845972327350054
#           0
# 10777     0
# 1991      1
# 869       2
# 734       3
# 846       4
# ...     ...
# 728     251
# 1284    252
# 3478    253
# 7168    254
# 227917  255
#
# [143 rows x 1 columns]
# 0
# 21.995546402669817 104.79765236022202 12.278446184524716
#          0
# 1055     0
# 6204     1
# 10228    2
# 8574     3
# 10107    4
# ...    ...
# 1393   251
# 1170   252
# 1769   253
# 1893   254
# 264    255
#
# [256 rows x 1 columns]
# 0
# 37.70220350446142 53.13182029347687 79.8711021351964
#           0
# 18366     0
# 3010      1
# 517       2
# 37        3
# 1       134
# ...     ...
# 83816   251
# 38089   252
# 15476   253
# 12260   254
# 296089  255
#
# [123 rows x 1 columns]
# 0
# 222.90645737717065 222.90645737717065 222.90645737717065
#          0
# 2726     0
# 16111    1
# 21131    2
# 16741    3
# 17878    4
# ...    ...
# 2603   251
# 2889   252
# 3778   253
# 4693   254
# 1012   255
#
# [256 rows x 1 columns]
# 0
# 70.06130116721934 120.263236345396 69.90653634819941
#           0
# 10624     0
# 2876      1
# 1014      2
# 2321      3
# 7661      4
# ...     ...
# 667     251
# 1024    252
# 2973    253
# 6896    254
# 229653  255
#
# [137 rows x 1 columns]
# 0
# 20.33617088667886 85.03696916438042 12.269094840725499
#           0
# 109888    0
# 25428     1
# 44124     2
# 27236     3
# 28497     4
# ...     ...
# 1404    251
# 978     252
# 894     253
# 1376    254
# 6842    255
#
# [256 rows x 1 columns]
# 0
# 132.1885086695353 102.41235605875652 128.64822800954184
#           0
# 108961    0
# 3133      1
# 3488      2
# 2177      3
# 2098      4
# ...     ...
# 531     251
# 334     252
# 315     253
# 956     254
# 6691    255
#
# [192 rows x 1 columns]
# 0
# 137.1450293858846 94.70459206899007 126.52669556935628
#         0
# 900     0
# 4864    1
# 8300    2
# 6979    3
# 8225    4
# ...   ...
# 210   251
# 246   252
# 222   253
# 363   254
# 62    255
#
# [256 rows x 1 columns]
# 1464
#         0
# 750     0
# 4617    1
# 8310    2
# 7074    3
# 8575    4
# ...   ...
# 81    251
# 58    252
# 37    253
# 20    254
# 1     255
#
# [256 rows x 1 columns]
# 1512
#           0
# 9180      0
# 1242      1
# 1177      2
# 1165      3
# 362       4
# ...     ...
# 1228    251
# 2438    252
# 4588    253
# 4915    254
# 227036  255
#
# [176 rows x 1 columns]
# 0
# 23.014346136259718 171.97185011335924 12.38022917142966
#           0
# 109265    0
# 4421      1
# 5958      2
# 5984      3
# 8413      4
# ...     ...
# 5443    251
# 5191    252
# 6903    253
# 9915    254
# 143092  255
#
# [256 rows x 1 columns]
# 0
# 117.46174303690593 118.40844122568767 134.27346261342367
#           0
# 10395     0
# 2508      1
# 699       2
# 646       3
# 494       4
# ...     ...
# 716     251
# 1333    252
# 3110    253
# 7948    254
# 228065  255
#
# [150 rows x 1 columns]
# 0
# 22.919242652288776 114.46277006172839 12.307267653241375
#           0
# 16637     0
# 40341     1
# 55909     2
# 45393     3
# 46427     4
# ...     ...
# 4017    251
# 4081    252
# 4822    253
# 8676    254
# 274436  255
#
# [256 rows x 1 columns]
# 0
# 68.56776415120787 84.2598577370082 74.34018103513873
#         0
# 1105    0
# 5702    1
# 8424    2
# 7051    3
# 8277    4
# ...   ...
# 54    250
# 63    251
# 37    252
# 26    253
# 8     254
#
# [255 rows x 1 columns]
# 1536
#           0
# 111540    0
# 4672      1
# 5665      2
# 9848      3
# 19477     4
# ...     ...
# 910     251
# 793     252
# 858     253
# 1678    254
# 7210    255
#
# [256 rows x 1 columns]
# 0
# 28.73180389404297 28.733009656270344 28.913658142089844
#          0
# 2729     0
# 14933    1
# 20275    2
# 16266    3
# 17098    4
# ...    ...
# 2586   251
# 2733   252
# 3592   253
# 4692   254
# 1004   255
#
# [256 rows x 1 columns]
# 0
# 125.67998235854799 101.98193227965206 131.517732312492
#          0
# 933      0
# 7695     1
# 13858    2
# 13501    3
# 10482    4
# ...    ...
# 126    251
# 104    252
# 79     253
# 22     254
# 1      255
#
# [256 rows x 1 columns]
# 1528
#           0
# 9800      0
# 1249      1
# 1230      2
# 943       3
# 455       4
# ...     ...
# 1689    251
# 2391    252
# 4620    253
# 4286    254
# 225669  255
#
# [185 rows x 1 columns]
# 0
# 25.156369471752274 194.68241788599298 12.35057417885993
#         0
# 996     0
# 5314    1
# 8979    2
# 7262    3
# 8416    4
# ...   ...
# 75    251
# 43    252
# 37    253
# 18    254
# 1     255
#
# [256 rows x 1 columns]
# 1352
#          0
# 2312     0
# 13043    1
# 18374    2
# 15213    3
# 16720    4
# ...    ...
# 7472   251
# 6697   252
# 7734   253
# 11454  254
# 4452   255
#
# [256 rows x 1 columns]
# 232
#         0
# 603     0
# 3340    1
# 5366    2
# 4133    3
# 4742    4
# ...   ...
# 44    250
# 40    251
# 41    252
# 32    253
# 24    254
#
# [255 rows x 1 columns]
# 0
# 20.332534361783928 28.611676924139754 103.89686934312124
#          0
# 1802     0
# 7314     1
# 11209    2
# 9832     3
# 11137    4
# ...    ...
# 1701   251
# 1540   252
# 2307   253
# 2871   254
# 526    255
#
# [256 rows x 1 columns]
# 1056
#         0
# 922     0
# 4958    1
# 7920    2
# 6312    3
# 7324    4
# ...   ...
# 55    250
# 42    251
# 53    252
# 28    253
# 13    254
#
# [255 rows x 1 columns]
# 1712
#         0
# 317     0
# 2412    1
# 4842    2
# 4627    3
# 5834    4
# ...   ...
# 591   251
# 486   252
# 519   253
# 302   254
# 53    255
#
# [256 rows x 1 columns]
# 1648
#        0
# 233    0
# 869    1
# 979    2
# 767    3
# 903    4
# ..   ...
# 10   249
# 34   250
# 3    251
# 4    252
# 6    253
#
# [254 rows x 1 columns]
# 688
#           0
# 15372     0
# 41261     1
# 55226     2
# 44797     3
# 45955     4
# ...     ...
# 4313    251
# 4723    252
# 6178    253
# 11031   254
# 273788  255
#
# [256 rows x 1 columns]
# 0
# 67.42158952786589 82.37314549492183 72.95525521534185
#         0
# 540     0
# 2813    1
# 4194    2
# 3634    3
# 4390    4
# ...   ...
# 14    249
# 6     250
# 4     251
# 2     252
# 1     253
#
# [254 rows x 1 columns]
# 0
# 36.25912334398629 105.69507158204377 85.8991217069957
#           0
# 10844     0
# 2547      1
# 790       2
# 3491      3
# 9876      4
# ...     ...
# 649     251
# 1564    252
# 3068    253
# 7435    254
# 227531  255
#
# [133 rows x 1 columns]
# 0
# 13.254032072410201 96.40770330837525 12.255937865162831
#          0
# 2370     0
# 13040    1
# 18370    2
# 15147    3
# 16548    4
# ...    ...
# 6331   251
# 5942   252
# 6720   253
# 9806   254
# 3733   255
#
# [256 rows x 1 columns]
# 392
#           0
# 11142     0
# 2224      1
# 834       2
# 1012      3
# 2799      4
# ...     ...
# 797     251
# 1388    252
# 3232    253
# 7699    254
# 228023  255
#
# [149 rows x 1 columns]
# 0
# 20.774995395773 89.07573358037392 12.279486700134633
#         0
# 923     0
# 5108    1
# 7396    2
# 6008    3
# 6796    4
# ...   ...
# 42    250
# 33    251
# 43    252
# 41    253
# 1     254
#
# [255 rows x 1 columns]
# 1112
#           0
# 10068     0
# 1241      1
# 904       2
# 833       3
# 440       4
# ...     ...
# 1713    251
# 2524    252
# 3836    253
# 5063    254
# 225909  255
#
# [181 rows x 1 columns]
# 0
# 24.531766387872782 187.68118526298073 12.376923852436112
#           0
# 11087     0
# 2322      1
# 757       2
# 1186      3
# 3956      4
# ...     ...
# 857     251
# 1371    252
# 3115    253
# 7757    254
# 228134  255
#
# [148 rows x 1 columns]
# 0
# 20.741365089798304 89.13858882030178 12.280595286859219
#           0
# 10529     0
# 4324      1
# 10725     2
# 12972     3
# 11910     4
# ...     ...
# 3957    251
# 3655    252
# 4420    253
# 9003    254
# 278823  255
#
# [256 rows x 1 columns]
# 0
# 75.67019433130687 69.86609354475041 68.92670186947328
#           0
# 7543      0
# 2312      1
# 1094      2
# 1178      3
# 545       4
# ...     ...
# 93257   251
# 127739  252
# 110997  253
# 99640   254
# 373226  255
#
# [256 rows x 1 columns]
# 0
# 154.9819297982396 178.05606976038968 165.70558707069551
#         0
# 198     0
# 2077    1
# 3813    2
# 3492    3
# 4315    4
# ...   ...
# 639   251
# 552   252
# 464   253
# 256   254
# 24    255
#
# [256 rows x 1 columns]
# 1544
#           0
# 10094     0
# 818       1
# 1249      2
# 1083      3
# 392       4
# ...     ...
# 1797    251
# 2387    252
# 4766    253
# 4333    254
# 225369  255
#
# [185 rows x 1 columns]
# 0
# 25.356952224000405 195.6251742461769 12.354540958568307
#           0
# 10493     0
# 440       1
# 665       2
# 597       3
# 889       4
# ...     ...
# 1675    251
# 2007    252
# 1890    253
# 218519  254
# 12471   255
#
# [256 rows x 1 columns]
# 24
# 106.02751978229945 143.04447008522584 124.9678027596784
#         0
# 199     0
# 1653    1
# 3048    2
# 3137    3
# 4307    4
# ...   ...
# 6     247
# 8     248
# 6     249
# 4     250
# 1     251
#
# [252 rows x 1 columns]
# 1568
#           0
# 10387     0
# 1018      1
# 574       2
# 341       3
# 771       4
# ...     ...
# 1926    251
# 2053    252
# 3349    253
# 5137    254
# 227583  255
#
# [178 rows x 1 columns]
# 0
# 23.61205418381344 177.57359519477467 12.384893729677895
#           0
# 10423     0
# 1709      1
# 687       2
# 837       3
# 488       4
# ...     ...
# 938     251
# 2013    252
# 4010    253
# 7261    254
# 225458  255
#
# [140 rows x 1 columns]
# 0
# 17.644259957831633 143.96552505652085 12.279828643372454
#         0
# 921     0
# 5791    1
# 9595    2
# 8241    3
# 9725    4
# ...   ...
# 678   251
# 592   252
# 861   253
# 1039  254
# 212   255
#
# [256 rows x 1 columns]
# 1408
#          0
# 1895     0
# 9934     1
# 14820    2
# 12836    3
# 14204    4
# ...    ...
# 2838   251
# 2744   252
# 3519   253
# 5186   254
# 2232   255
#
# [256 rows x 1 columns]
# 864
#           0
# 11125     0
# 2245      1
# 937       2
# 1549      3
# 6261      4
# ...     ...
# 684     251
# 1205    252
# 3244    253
# 7362    254
# 229018  255
#
# [137 rows x 1 columns]
# 0
# 20.884134230681298 87.29711414196261 12.282846595094751
#         0
# 1068    0
# 4883    1
# 7469    2
# 6086    3
# 6932    4
# ...   ...
# 74    251
# 76    252
# 69    253
# 25    254
# 1     255
#
# [256 rows x 1 columns]
# 1464
#           0
# 10984     0
# 2148      1
# 747       2
# 702       3
# 921       4
# ...     ...
# 816     251
# 1255    252
# 2842    253
# 7743    254
# 227650  255
#
# [141 rows x 1 columns]
# 0
# 21.97535865340649 106.43963759176701 12.263639228649089
#           0
# 10386     0
# 3943      1
# 8401      2
# 9833      3
# 13926     4
# ...     ...
# 2604    251
# 3164    252
# 4581    253
# 9510    254
# 273061  255
#
# [256 rows x 1 columns]
# 0
# 91.68693631455851 115.64818656986895 101.24857664419935
#           0
# 108820    0
# 4163      1
# 5762      2
# 5349      3
# 6461      4
# ...     ...
# 15741   251
# 14541   252
# 25813   253
# 44713   254
# 166804  255
#
# [256 rows x 1 columns]
# 0
# 142.08710289001465 115.29155604044597 140.36472288767496
#         0
# 1174    0
# 5494    1
# 8310    2
# 7076    3
# 8393    4
# ...   ...
# 1230  251
# 1170  252
# 1896  253
# 2207  254
# 328   255
#
# [256 rows x 1 columns]
# 584
#           0
# 10772     0
# 1642      1
# 1295      2
# 699       3
# 715       4
# ...     ...
# 969     251
# 1761    252
# 3823    253
# 6670    254
# 226602  255
#
# [147 rows x 1 columns]
# 0
# 21.68185823426307 120.96771563658996 12.260874112495555
#         0
# 310     0
# 1248    1
# 1677    2
# 1363    3
# 1512    4
# ...   ...
# 28    250
# 16    251
# 20    252
# 13    253
# 1     254
#
# [255 rows x 1 columns]
# 1880
#           0
# 11388     0
# 2056      1
# 961       2
# 600       3
# 601       4
# ...     ...
# 584     251
# 930     252
# 2668    253
# 6794    254
# 230551  255
#
# [127 rows x 1 columns]
# 0
# 21.451962829599147 129.0507473136717 12.283749579268912
#           0
# 9880      0
# 1886      1
# 824       2
# 842       3
# 458       4
# ...     ...
# 857     251
# 2110    252
# 3464    253
# 7508    254
# 226165  255
#
# [138 rows x 1 columns]
# 0
# 17.64560510656404 144.40231537049738 12.296591006515776
#           0
# 10004     0
# 1861      1
# 833       2
# 4177      3
# 5200      4
# ...     ...
# 976     251
# 2286    252
# 3567    253
# 7123    254
# 225762  255
#
# [149 rows x 1 columns]
# 0
# 16.493975408664838 143.13464486327032 12.285967546550323
#          0
# 2519     0
# 485      1
# 688      2
# 774      3
# 894      4
# ...    ...
# 23039  251
# 7802   252
# 2358   253
# 1252   254
# 759    255
#
# [256 rows x 1 columns]
# 0
# 157.6163345 143.44269716666668 158.54265833333332
#           0
# 10411     0
# 2884      1
# 974       2
# 2183      3
# 7973      4
# ...     ...
# 571     251
# 1063    252
# 2816    253
# 6880    254
# 230319  255
#
# [138 rows x 1 columns]
# 0
# 20.419862833727073 85.02349406054718 12.288451050716354
#           0
# 10789     0
# 1683      1
# 1273      2
# 682       3
# 716       4
# ...     ...
# 967     251
# 1727    252
# 3933    253
# 6596    254
# 226674  255
#
# [145 rows x 1 columns]
# 0
# 21.682460157559824 120.95550193218767 12.261161479766804
#           0
# 9904      0
# 822       1
# 1218      2
# 1051      3
# 386       4
# ...     ...
# 1720    251
# 2359    252
# 4933    253
# 4278    254
# 225728  255
#
# [185 rows x 1 columns]
# 0
# 25.3454007741452 195.22848258173298 12.367122008840116
#           0
# 7487      0
# 2878      1
# 727       2
# 1361      3
# 1079      4
# ...     ...
# 4393    251
# 4470    252
# 5598    253
# 5301    254
# 227836  255
#
# [256 rows x 1 columns]
# 0
# 129.78899879496265 149.1482148300564 137.84028730376468
#         0
# 738     0
# 4264    1
# 7543    2
# 6477    3
# 7897    4
# ...   ...
# 82    251
# 56    252
# 83    253
# 39    254
# 2     255
#
# [256 rows x 1 columns]
# 1656
#           0
# 9387      0
# 1223      1
# 1143      2
# 1155      3
# 367       4
# ...     ...
# 1329    251
# 2464    252
# 4647    253
# 4750    254
# 226607  255
#
# [176 rows x 1 columns]
# 0
# 23.222199201087232 171.95214243414367 12.366454395925418
#           0
# 9563      0
# 7591      1
# 11485     2
# 9610      3
# 11041     4
# ...     ...
# 8790    251
# 11050   252
# 15354   253
# 24443   254
# 275543  255
#
# [256 rows x 1 columns]
# 0
# 109.62489124275119 135.7094080151464 123.10715842965045
#           0
# 10155     0
# 1484      1
# 1406      2
# 492       3
# 609       4
# ...     ...
# 1066    251
# 1920    252
# 4082    253
# 6635    254
# 225972  255
#
# [152 rows x 1 columns]
# 0
# 16.993016657775744 148.86377779206677 12.28556090598486
#         0
# 1045    0
# 6157    1
# 9515    2
# 8263    3
# 9816    4
# ...   ...
# 1067  251
# 978   252
# 1452  253
# 1486  254
# 220   255
#
# [256 rows x 1 columns]
# 1352
#         0
# 893     0
# 5619    1
# 9603    2
# 8312    3
# 9973    4
# ...   ...
# 778   251
# 673   252
# 924   253
# 1207  254
# 260   255
#
# [256 rows x 1 columns]
# 952
#         0
# 69      0
# 691     1
# 1562    2
# 1646    3
# 2076    4
# ...   ...
# 447   251
# 406   252
# 384   253
# 263   254
# 36    255
#
# [256 rows x 1 columns]
# 1863
#           0
# 9380      0
# 1251      1
# 1136      2
# 1168      3
# 360       4
# ...     ...
# 1268    251
# 2485    252
# 4482    253
# 4912    254
# 226662  255
#
# [178 rows x 1 columns]
# 0
# 23.097263501498755 171.97326055479348 12.366831267781842
#           0
# 111419    0
# 12354     1
# 16569     2
# 10644     3
# 11040     4
# ...     ...
# 517     251
# 293     252
# 293     253
# 921     254
# 6028    255
#
# [256 rows x 1 columns]
# 0
# 105.86017417907715 90.36057217915852 111.23552799224854
#           0
# 110555    0
# 3688      1
# 2762      2
# 2855      3
# 4855      4
# ...     ...
# 932     251
# 795     252
# 817     253
# 1942    254
# 7431    255
#
# [256 rows x 1 columns]
# 0
# 59.084065755208336 59.08518918355306 59.265573501586914
#         0
# 973     0
# 5590    1
# 8710    2
# 7293    3
# 8969    4
# ...   ...
# 63    250
# 46    251
# 59    252
# 36    253
# 4     254
#
# [255 rows x 1 columns]
# 1512
#         0
# 1024    0
# 5740    1
# 9558    2
# 7967    3
# 9711    4
# ...   ...
# 796   251
# 658   252
# 897   253
# 1244  254
# 172   255
#
# [256 rows x 1 columns]
# 1296
#           0
# 110700    0
# 52141     1
# 110627    2
# 57434     3
# 49777     4
# ...     ...
# 2269    251
# 1761    252
# 2403    253
# 4890    254
# 25490   255
#
# [256 rows x 1 columns]
# 0
# 76.56572914123535 104.18640327453613 106.64996973673503
#           0
# 9866      0
# 3524      1
# 3313      2
# 3058      3
# 2933      4
# ...     ...
# 1338    251
# 1015    252
# 1462    253
# 219229  254
# 12604   255
#
# [256 rows x 1 columns]
# 24
# 74.63059790650561 73.14839701455571 71.86901311569629
#           0
# 10236     0
# 1853      1
# 675       2
# 386       3
# 307       4
# ...     ...
# 1394    251
# 2164    252
# 4299    253
# 4817    254
# 226468  255
#
# [184 rows x 1 columns]
# 0
# 25.0984177335772 195.25401222660417 12.367383179647412
#          0
# 17720    0
# 91781    1
# 99453    2
# 85453    3
# 69520    4
# ...    ...
# 1      129
# 2      132
# 1      135
# 2      137
# 1      142
#
# [132 rows x 1 columns]
# 2192
#         0
# 287     0
# 1492    1
# 2308    2
# 2043    3
# 2428    4
# ...   ...
# 4     250
# 7     251
# 6     252
# 6     253
# 2     254
#
# [255 rows x 1 columns]
# 1472
#          0
# 1073     0
# 6285     1
# 10275    2
# 8633     3
# 10570    4
# ...    ...
# 1227   251
# 1050   252
# 1408   253
# 1629   254
# 241    255
#
# [256 rows x 1 columns]
# 1336
#           0
# 10798     0
# 2567      1
# 735       2
# 4120      3
# 11557     4
# ...     ...
# 723     251
# 1625    252
# 3016    253
# 7513    254
# 227557  255
#
# [133 rows x 1 columns]
# 0
# 13.192833163453233 96.72535428732917 12.260647076474623
#           0
# 17454     0
# 2899      1
# 1121      2
# 293       3
# 81        4
# ...     ...
# 95      251
# 714     252
# 2481    253
# 7385    254
# 293856  255
#
# [145 rows x 1 columns]
# 0
# 193.13298871427656 193.13298871427656 193.13298871427656
#          0
# 679      0
# 4903     1
# 8415     2
# 7389     3
# 9223     4
# ...    ...
# 8810   251
# 9455   252
# 10346  253
# 10993  254
# 3207   255
#
# [256 rows x 1 columns]
# 664
#           0
# 10547     0
# 44234     1
# 70760     2
# 75364     3
# 124574    4
# ...     ...
# 1862    251
# 2745    252
# 3310    253
# 3501    254
# 225100  255
#
# [189 rows x 1 columns]
# 0
# 24.028219346961844 86.3959293870345 21.88353687191993
#           0
# 109187    0
# 3164      1
# 3640      2
# 2003      3
# 2034      4
# ...     ...
# 522     251
# 304     252
# 298     253
# 979     254
# 6662    255
#
# [188 rows x 1 columns]
# 0
# 138.17453289031982 95.53630034128825 127.4747486114502
#           0
# 11121     0
# 2305      1
# 655       2
# 610       3
# 587       4
# ...     ...
# 956     251
# 1447    252
# 3142    253
# 7259    254
# 226685  255
#
# [153 rows x 1 columns]
# 0
# 20.986982738911752 125.2865748282147 12.24297240162831
#           0
# 9824      0
# 2169      1
# 1074      2
# 510       3
# 539       4
# ...     ...
# 1042    251
# 1683    252
# 4573    253
# 7335    254
# 225603  255
#
# [148 rows x 1 columns]
# 0
# 16.718662281537366 157.3604270261774 12.29682022557537
#        0
# 155    0
# 668    1
# 939    2
# 718    3
# 888    4
# ..   ...
# 6    250
# 8    251
# 10   252
# 17   253
# 7    254
#
# [255 rows x 1 columns]
# 1912
#           0
# 9911      0
# 1904      1
# 789       2
# 809       3
# 525       4
# ...     ...
# 889     251
# 2227    252
# 3391    253
# 7529    254
# 226061  255
#
# [137 rows x 1 columns]
# 0
# 17.643881299852666 144.1555053853579 12.29654853649088
#         0
# 813     0
# 4677    1
# 7254    2
# 5873    3
# 6715    4
# ...   ...
# 53    251
# 46    252
# 36    253
# 31    254
# 1     255
#
# [256 rows x 1 columns]
# 1744
#         0
# 728     0
# 4479    1
# 7536    2
# 6372    3
# 7730    4
# ...   ...
# 8873  251
# 2743  252
# 682   253
# 136   254
# 10    255
#
# [256 rows x 1 columns]
# 0
# 182.4710356543557 168.35410158753044 190.43918942934607
#           0
# 9699      0
# 2064      1
# 1049      2
# 447       3
# 493       4
# ...     ...
# 1162    251
# 2002    252
# 4170    253
# 7058    254
# 225675  255
#
# [150 rows x 1 columns]
# 0
# 17.073695416095106 149.8396895480872 12.30033710086115

# %%
# !rm -r /content/g

# %%
im_pr=cv2.imread('/content/g/broken_91.JPG.jpg') # проверка на 1 файле
gray_image = cv2.cvtColor(im_pr, cv2.COLOR_BGR2GRAY)
print(colors(gray_image),koeff(gray_image))
chanal_bad(im_pr)
# Out:
#         0
# 586     0
# 2859    1
# 4522    2
# 5533    3
# 7259    4
# ...   ...
# 7109  251
# 7682  252
# 8123  253
# 7462  254
# 2334  255
#
# [256 rows x 1 columns]
# 0
# 1 (156.64998337978983, 0.010015929370114059, 0.006357981305267205, 0.09161302644015122)
# 159.04669765935378 119.23059928372902 175.27214730612425
# 0
